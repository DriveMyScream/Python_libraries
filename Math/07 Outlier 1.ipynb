# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Reading the data set from the folder

# %%
df = pd.read_csv("Room data.csv")
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
df.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13200.000000  13200.000000  13200.000000  13200.000000    1.320000e+04
# mean    1555.302783      2.691136    112.276178      2.800833    7.920337e+03
# std     1237.323445      1.338915    149.175995      1.292843    1.067272e+05
# min        1.000000      1.000000      8.000000      1.000000    2.670000e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.267000e+03
# 50%     1275.000000      2.000000     71.850000      3.000000    5.438000e+03
# 75%     1672.000000      3.000000    120.000000      3.000000    7.317000e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %% [markdown]
# #### from describe function we get the minimum, maximum, mean, standard deviation information of the data set

# %%
plt.hist(df["price_per_sqft"], bins=20, rwidth=0.8)
plt.xlabel("Price per square ft")
plt.ylabel("Count")
plt.show()

# %%
plt.hist(df["price_per_sqft"], bins=20, rwidth=0.8)
plt.xlabel("Price per square ft")
plt.ylabel("Count")
plt.yscale("log")
plt.show()

# %% [markdown]
# ### treating the outlier using persentile

# %%
lower_limit, upper_limit = df["price_per_sqft"].quantile([0.001, 0.999])

# %%
newdf = df[(df["price_per_sqft"]>lower_limit) & (df["price_per_sqft"] < upper_limit)]
newdf
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
newdf.shape
# Out:
# (13172, 7)

# %%
outlier1 = df[(df["price_per_sqft"] < lower_limit) | (df["price_per_sqft"] > upper_limit)]
outlier1
# Out:
#                 location       size  total_sqft  bath   price  bhk  \
# 345                other  3 Bedroom        11.0   3.0    74.0    3
# 665            Yelahanka      3 BHK     35000.0   3.0   130.0    3
# 798                other  4 Bedroom     10961.0   4.0    80.0    4
# 1005               other      1 BHK        15.0   1.0    30.0    1
# 1106               other  5 Bedroom        24.0   2.0   150.0    5
# 1867               other  3 Bedroom     52272.0   2.0   140.0    3
# 2392               other  4 Bedroom      2000.0   3.0    25.0    4
# 3934               other      1 BHK      1500.0   1.0    19.5    1
# 4044      Sarjapur  Road  4 Bedroom         1.0   4.0   120.0    4
# 4924               other      7 BHK         5.0   7.0   115.0    7
# 5343               other      9 BHK     42000.0   8.0   175.0    9
# 5417              Ulsoor      4 BHK     36000.0   4.0   450.0    4
# 5597            JP Nagar      2 BHK      1100.0   1.0    15.0    2
# ...

# %% [markdown]
# #### so we are removing the total 196 number of outlier from the data set

# %%
plt.hist(newdf["price_per_sqft"], bins=20, rwidth=0.8)
plt.xlabel("price per sqft")
plt.ylabel("count")
plt.show()

# %% [markdown]
# ### Outlier removing using

# %%
max_limit = newdf["price_per_sqft"].mean() + 4 * newdf["price_per_sqft"].std()
min_limit = newdf["price_per_sqft"].mean() - 4 * newdf["price_per_sqft"].std()
max_limit, min_limit
# Out:
# (23227.73653589432, -9900.429065502582)

# %%
newdf1 = newdf[(newdf["price_per_sqft"]>min_limit) & (newdf["price_per_sqft"] < max_limit)]
newdf1
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
outlier2 = newdf[(newdf["price_per_sqft"] < min_limit) | (newdf["price_per_sqft"] > max_limit)]
outlier2
# Out:
#               location       size  total_sqft  bath   price  bhk  \
# 9                other  6 Bedroom      1020.0   6.0   370.0    6
# 45          HSR Layout  8 Bedroom       600.0   9.0   200.0    8
# 190          Bellandur  4 Bedroom      1200.0   5.0   325.0    4
# 733    Cunningham Road      4 BHK      5270.0   4.0  1250.0    4
# 760              other  9 Bedroom       600.0   9.0   190.0    9
# ...                ...        ...         ...   ...     ...  ...
# 13081            other  6 Bedroom      8000.0   6.0  2800.0    6
# 13094            other  4 Bedroom      1200.0   5.0   325.0    4
# 13127            other  4 Bedroom      1200.0   5.0   325.0    4
# 13185         Hulimavu      1 BHK       500.0   1.0   220.0    1
# 13186            other  4 Bedroom      1200.0   5.0   325.0    4
#
#        price_per_sqft
# 9               36274
# 45              33333
# 190             27083
# 733             23719
# 760             31666
# ...               ...
# ...

# %% [markdown]
# #### so we are removing the total 125 number of outlier from the data set

# %%
plt.hist(newdf1["price_per_sqft"], bins=20, rwidth=0.8)
plt.xlabel("price per sqft")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Remove with the help of zscore

# %%
a = newdf1["price_per_sqft"]
b = newdf1["price_per_sqft"].mean()
c = newdf1["price_per_sqft"].std()

# %%
newdf1["Z score"] = (a - b) / c
newdf1
# Out:
# c:\users\abc\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# ...

# %%
newdf2 = newdf1[(newdf1["Z score"]) > -4 & (newdf1["Z score"] < 4)]
newdf2
# Out:
#                 location       size  total_sqft  bath  price  bhk  \
# 6       Old Airport Road      4 BHK      2732.0   4.0  204.0    4
# 7           Rajaji Nagar      4 BHK      3300.0   4.0  600.0    4
# 11            Whitefield  4 Bedroom      2785.0   5.0  295.0    4
# 14              Sarjapur  3 Bedroom      2250.0   3.0  148.0    3
# 18                 other      3 BHK      2770.0   4.0  290.0    3
# ...                  ...        ...         ...   ...    ...  ...
# 13191   Ramamurthy Nagar  7 Bedroom      1500.0   9.0  250.0    7
# 13194  Green Glen Layout      3 BHK      1715.0   3.0  112.0    3
# 13195         Whitefield  5 Bedroom      3453.0   4.0  231.0    5
# 13196              other      4 BHK      3600.0   5.0  400.0    4
# 13198    Padmanabhanagar      4 BHK      4689.0   4.0  488.0    4
#
#        price_per_sqft   Z score
# 6                7467  0.291791
# 7               18181  3.363756
# 11              10592  1.187805
# 14               6577  0.036607
# ...

# %%
outlier3 = newdf1[(newdf1["Z score"] < -4) | (newdf1["Z score"] > 4)]
outlier3
# Out:
#                    location       size  total_sqft  bath  price  bhk  \
# 87             Rajaji Nagar  6 Bedroom       710.0   6.0  160.0    6
# 408      Mahalakshmi Layout  6 Bedroom      1200.0   7.0  250.0    6
# 429      7th Phase JP Nagar  8 Bedroom      1200.0   8.0  250.0    8
# 475                   other      4 BHK      1150.0   4.0  260.0    4
# 925      5th Phase JP Nagar  9 Bedroom      1260.0  11.0  290.0    9
# ...                     ...        ...         ...   ...    ...  ...
# 12084            Nagarbhavi  5 Bedroom      1200.0   5.0  260.0    5
# 12245    5th Phase JP Nagar  8 Bedroom      1200.0   7.0  250.0    8
# 12321  2nd Stage Nagarbhavi  3 Bedroom       600.0   5.0  135.0    3
# 12368           Koramangala  4 Bedroom      2400.0   5.0  550.0    4
# 12523                 other  4 Bedroom      2400.0   4.0  500.0    4
#
#        price_per_sqft   Z score
# 87              22535  4.612154
# 408             20833  4.124149
# 429             20833  4.124149
# ...

# %% [markdown]
# #### so we are removing the total 86 number of outlier from the data set

# %%
plt.hist(newdf2["price_per_sqft"], bins=20, rwidth=0.8)
plt.xlabel("price per sqft")
plt.ylabel("count")
plt.show();

# %%
from scipy.stats import norm
import numpy as np

plt.hist(newdf2.price_per_sqft, bins=20, rwidth=0.8, density=True)
plt.xlabel('Height (inches)')
plt.ylabel('Count')

rng = np.arange(-5000, newdf2.price_per_sqft.max(), 100)
plt.plot(rng, norm.pdf(rng,newdf2.price_per_sqft.mean(),newdf2.price_per_sqft.std()))

# %%
total = outlier1.shape[0] + outlier2.shape[0] + outlier3.shape[0]
total
# Out:
# 239
